# %% [markdown]
# # **Prompts in Langraph**
# In this file we will learn about prompts in langraph

# %%
import os

os.environ.pop("CURL_CA_BUNDLE", None)

print("CURL_CA_BUNDLE =", os.environ.get("CURL_CA_BUNDLE"))
# Out:
# CURL_CA_BUNDLE = None

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

from dotenv import load_dotenv
import os
load_dotenv()


if os.environ['GEMINI_API_KEY']:
    print('gemini key set')
else:
    print("not set")
# Out:
# gemini key set

# %% [markdown]
# # **Initialize LLM**

# %%
# Initialize the Gemini model
llm = ChatGoogleGenerativeAI(
    model="gemini-3.1-flash-lite",
    temperature=0.7,
    max_tokens=None,
    timeout=None,
    max_retries=2,
)

llm
# Out:
# ChatGoogleGenerativeAI(metadata={'lc_versions': {'langchain-core': '1.5.5', 'langchain-google-genai': '4.3.4'}}, profile={'name': 'Gemini 3.1 Flash Lite', 'release_date': '2026-05-07', 'last_updated': '2026-05-07', 'open_weights': False, 'max_input_tokens': 1048576, 'max_output_tokens': 65536, 'text_inputs': True, 'image_inputs': True, 'audio_inputs': True, 'pdf_inputs': True, 'video_inputs': True, 'text_outputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': True, 'tool_calling': True, 'structured_output': True, 'attachment': True, 'temperature': True, 'image_url_inputs': True, 'image_tool_message': True, 'tool_choice': True, 'reasoning_effort_levels': ['minimal', 'low', 'medium', 'high'], 'reasoning_effort_default': 'minimal'}, google_api_key=SecretStr('**********'), model='gemini-3.1-flash-lite', max_retries=2, client=<google.genai.client.Client object at 0x0000019B795B4830>, default_metadata=(), model_kwargs={})

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.messages import HumanMessage, SystemMessage, AIMessage

my_prompt = ChatPromptTemplate.from_messages(
    [
        ("system","you're a helpful assistant that helps create and curate posts for a social media platform."),
        ("human","I want to create a post about {topic}")
    ]
)

# %%
# prompt_filled = my_prompt.invoke({"topic":"the importance of data privacy in this digital era"})

# %%
# llm.invoke(prompt_filled)
# Out:
# Direct use of automatic function calling (AFC) in Models.generate_content is not recommended. Instead, we recommend to use AFC in Chat.send_message. Similarly, direct use of AFC in Models.generate_content_stream is not recommended. Instead, we recommend to use AFC in Chat.send_message_stream.
# ...

# %% [markdown]
# # **Chain With Prompts**

# %%
chain = my_prompt | llm

# %%
chain.invoke({"topic":"importance of data privacy in the digital age"})
# Out:
# AIMessage(content=[{'type': 'text', 'text': 'To create an effective post about data privacy, you need to balance **urgency** (why it matters) with **empowerment** (what they can do about it).\n\nDepending on your platform and brand voice, here are four different options:\n\n### Option 1: The "Wake-Up Call" (Best for LinkedIn/Professional)\n**Headline:** Data is the new oil, but are you the refinery or the product? 🛢️\n\n**Body:**\nIn the digital age, our personal data is constantly being harvested, analyzed, and traded. We trade our privacy for convenience every single day—a free app here, a personalized ad there. \n\nBut privacy isn\'t just about "having nothing to hide." It’s about having the power to decide what you share, with whom, and for what purpose. \n\n**3 ways to reclaim your digital footprint:**\n1. **Audit your permissions:** Check which apps have access to your location and camera.\n2. **Use an Authenticator App:** Move away from SMS-based 2FA for better security.\n3. *
# ...
